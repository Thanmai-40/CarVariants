# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
# Out:
# F:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# F:\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
url = f"https://www.autocarindia.com/car-news/volkswagen-virtus-price-variants-explained-424751"
request = requests.get(url)
doc = BeautifulSoup(request.content)

# %%
volkswagan_variants = doc.find("div", attrs = {"class" : "news_article_body"})

# %%
found_tags = volkswagan_variants.find_all(lambda tag: tag.name in ['p', 'h2'] and tag.find('span', attrs = {"style" : "color:#ff0000"}))

# %%
variant_names = []
ul_contents_list = []

for tag in found_tags:
     
    next_sibling = tag.find_next_sibling()
    
    if next_sibling and next_sibling.name == 'p':
        next_next_sibling = next_sibling.find_next_sibling()
        if not next_next_sibling or next_next_sibling.name != 'p':
            next_ul = tag.find_next(lambda t: t.name == 'ul' and not t.attrs)
            variant_names.append(tag.string)  
        else:
            continue
            
    elif next_sibling and next_sibling.name != 'p':
        next_ul = tag.find_next(lambda t: t.name == 'ul' and not t.attrs)
        variant_names.append(tag.string)
        
    if next_ul:
        ul_tags = list(next_ul.strings)
       
        if ul_tags not in ul_contents_list:
            ul_contents_list.append(ul_tags)
        
    else:
        print("No <ul> tag found")

# %%
features = {}
for idx, ul_content in enumerate(ul_contents_list):
    features[variant_names[idx]] = ul_content

# %%
total_features = list(features.values())
All_Features = [item for sublist in total_features for item in sublist]

# %%
base = []

for variant in features:
    original_features = features[variant]
    
    features[variant] = features[variant] + base
    
    base = base + original_features

# %%
Car_Features = {
    'Features' : All_Features
}

# %%
df = pd.DataFrame(Car_Features)

# %%
for variant in features:
    df[variant] = df['Features'].isin(features[variant])

# %%
print(df)
# Out:
#                                     Features  \
# 0                LED headlamps with LED DRLs
# 1                             LED tail-lamps
# 2           16-inch steel wheels with covers
# 3        LED turn indicators on wing mirrors
# 4       Electrically adjustable wing mirrors
# 5                    Black fabric upholstery
# 6             Steering rake and reach adjust
# 7                     Engine idle start/stop
# 8          7.0-inch touchscreen infotainment
# 9             Android Auto and Apple CarPlay
# 10           Height adjustable driver’s seat
# 11                                8 speakers
# 12                              Dual airbags
# 13                                       ESC
# 14                              ABS with EBD
# 15                   Multi-collision braking
# 16              Electronic differential lock
# 17                     Tyre pressure warning
# 18                      Rear parking sensors
# 19                             Rear defogger
# 20                      16-inch alloy wheels
# 21                Power folding wing mirrors
# 22                 Chrome exterior garnishes
# 23         Fog lamps with cornering function
# 24                   Beige fabric upholstery
# 25          10-inch touchscreen infotainment
# 26   Wireless Apple CarPlay and Android Auto
# 27                   Wireless phone charging
# 28             60:40 split-folding rear seat
# 29             Front and rear centre armrest
# 30          Touch-based auto climate control
# 31                             Rear AC vents
# 32                      Keyless entry and go
# 33                    Push-button start/stop
# 34                            Cruise control
# 35                          Ambient lighting
# 36               Hill-start assist (AT only)
# 37                 Paddle shifters (AT only)
# 38                          Rear-view camera
# 39                   Automatic LED headlamps
# 40                  16-inch dual-tone alloys
# 41                       Rain sensing wipers
# 42                          Electric Sunroof
# 43       8.0-inch digital instrument cluster
# 44                    Ventilated front seats
# 45                    Connected car features
# 46             Auto-dimming rear-view mirror
# 47             Hill-start assist (MT and AT)
# 48              Passenger seat height adjust
# 49            Leather/leatherette upholstery
# 50                                 6 airbags
# 51              Black-painted 16-inch alloys
# 52   Contrasting black roof and wing mirrors
# 53                  Gloss black rear spoiler
# 54                 Red front brake callipers
# 55                          Aluminium pedals
# 56             Red interior ambient lighting
# 57  Dual-tone leather/leatherette upholstery
# 58         Cylinder de-activation technology
#
#     Volkswagen Virtus Comfortline (Rs 11.21 lakh)  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
# 5                                            True
# 6                                            True
# 7                                            True
# 8                                            True
# 9                                            True
# 10                                           True
# 11                                           True
# 12                                           True
# 13                                           True
# 14                                           True
# 15                                           True
# 16                                           True
# 17                                           True
# 18                                           True
# 19                                           True
# 20                                          False
# 21                                          False
# 22                                          False
# 23                                          False
# 24                                          False
# 25                                          False
# 26                                          False
# 27                                          False
# 28                                          False
# 29                                          False
# 30                                          False
# 31                                          False
# 32                                          False
# 33                                          False
# 34                                          False
# 35                                          False
# 36                                          False
# 37                                          False
# 38                                          False
# 39                                          False
# 40                                          False
# 41                                          False
# 42                                          False
# 43                                          False
# 44                                          False
# 45                                          False
# 46                                          False
# 47                                          False
# 48                                          False
# 49                                          False
# 50                                          False
# 51                                          False
# 52                                          False
# 53                                          False
# 54                                          False
# 55                                          False
# 56                                          False
# 57                                          False
# 58                                          False
#
#     Volkswagen Virtus Highline (Rs 12.97 lakh-14.41 lakh)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                                True
# 8                                                True
# 9                                                True
# 10                                               True
# 11                                               True
# 12                                               True
# 13                                               True
# 14                                               True
# 15                                               True
# 16                                               True
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                               True
# 22                                               True
# 23                                               True
# 24                                               True
# 25                                               True
# 26                                               True
# 27                                               True
# 28                                               True
# 29                                               True
# 30                                               True
# 31                                               True
# 32                                               True
# 33                                               True
# 34                                               True
# 35                                               True
# 36                                               True
# 37                                               True
# 38                                               True
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                              False
# 43                                              False
# 44                                              False
# 45                                              False
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                              False
# 50                                              False
# 51                                              False
# 52                                              False
# 53                                              False
# 54                                              False
# 55                                              False
# 56                                              False
# 57                                              False
# 58                                              False
#
#     Volkswagen Virtus Topline (Rs 14.41 lakh-15.71 lakh)  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                                True
# 8                                                True
# 9                                                True
# 10                                               True
# 11                                               True
# 12                                               True
# 13                                               True
# 14                                               True
# 15                                               True
# 16                                               True
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                               True
# 22                                               True
# 23                                               True
# 24                                               True
# 25                                               True
# 26                                               True
# 27                                               True
# 28                                               True
# 29                                               True
# 30                                               True
# 31                                               True
# 32                                               True
# 33                                               True
# 34                                               True
# 35                                               True
# 36                                               True
# 37                                               True
# 38                                               True
# 39                                               True
# 40                                               True
# 41                                               True
# 42                                               True
# 43                                               True
# 44                                               True
# 45                                               True
# 46                                               True
# 47                                               True
# 48                                               True
# 49                                               True
# 50                                               True
# 51                                              False
# 52                                              False
# 53                                              False
# 54                                              False
# 55                                              False
# 56                                              False
# 57                                              False
# 58                                              False
#
#     Volkswagen Virtus GT (Rs 17.91 lakh)
# 0                                   True
# 1                                   True
# 2                                   True
# 3                                   True
# 4                                   True
# 5                                   True
# 6                                   True
# 7                                   True
# 8                                   True
# 9                                   True
# 10                                  True
# 11                                  True
# 12                                  True
# 13                                  True
# 14                                  True
# 15                                  True
# 16                                  True
# 17                                  True
# 18                                  True
# 19                                  True
# 20                                  True
# 21                                  True
# 22                                  True
# 23                                  True
# 24                                  True
# 25                                  True
# 26                                  True
# 27                                  True
# 28                                  True
# 29                                  True
# 30                                  True
# 31                                  True
# 32                                  True
# 33                                  True
# 34                                  True
# 35                                  True
# 36                                  True
# 37                                  True
# 38                                  True
# 39                                  True
# 40                                  True
# 41                                  True
# 42                                  True
# 43                                  True
# 44                                  True
# 45                                  True
# 46                                  True
# 47                                  True
# 48                                  True
# 49                                  True
# 50                                  True
# 51                                  True
# 52                                  True
# 53                                  True
# 54                                  True
# 55                                  True
# 56                                  True
# 57                                  True
# 58                                  True
